# %% [markdown]
# # data-anon-pandas-poc

# %%
# %python
display(dbutils.fs.ls("dbfs:/FileStore/tables/"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>path</th><th>name</th><th>size</th></tr></thead><tbody><tr><td>dbfs:/FileStore/tables/uk_500-626ee.csv</td><td>uk_500-626ee.csv</td><td>97773</td></tr></tbody></table></div>

# %%
a = hash("alex")
b = hash("rolls")
print(a)
print(b)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">-3582899213683715780
# 943071512722952251
# </div>

# %%
import pandas as pd
import hashlib

# Define data frame. Bear in mind this could be changed to read_sql
df = pd.read_csv("/dbfs/FileStore/tables/uk_500-626ee.csv", delimiter=',', header=0)
# Sort values by first_name column
df.sort_values("first_name", axis=0, ascending=True, inplace=True, na_position='last')
# Select just the first_name and last_name columns. Drop others and define new dataframe df2.
df2 = df[['first_name','last_name']].dropna()
# output the data
print(df2.head())

# hash first_name limit 15
df2['first_name_hash'] = [hashlib.sha1(str.encode(str(i))).hexdigest()[:15] for i in df2['first_name']]
# hash last_name limit 15
df2['last_name_hash'] = [hashlib.sha1(str.encode(str(i))).hexdigest()[:15] for i in df2['last_name']]
# output the data
print(df2.head())

df3 = df2[['first_name_hash','last_name_hash']]
print(df3.head())

df4 = df3[['first_name_hash','last_name_hash']].rename(columns={'first_name_hash':'first_name','last_name_hash':'last_name'})
print(df4.head())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">    first_name   last_name
# 68     Abraham      Cratch
# 293     Adelle   Schantini
# 255     Adolph  Cunningham
# 481      Ahmad     Alsaqri
# 339     Alaine    Raterman
#     first_name   last_name  first_name_hash   last_name_hash
# 68     Abraham      Cratch  1a52173707ec6b1  b44e6feea99d8e7
# 293     Adelle   Schantini  b8bfff787f9431b  8123bb8f811250b
# 255     Adolph  Cunningham  6f4491f8e22b695  9da59ac908212ad
# 481      Ahmad     Alsaqri  53925a8f3f2ec4a  f871419ada1e282
# 339     Alaine    Raterman  a286eff253fdc3e  3145489fff9b0a7
#      first_name_hash   last_name_hash
# 68   1a52173707ec6b1  b44e6feea99d8e7
# 293  b8bfff787f9431b  8123bb8f811250b
# 255  6f4491f8e22b695  9da59ac908212ad
# 481  53925a8f3f2ec4a  f871419ada1e282
# 339  a286eff253fdc3e  3145489fff9b0a7
#           first_name        last_name
# 68   1a52173707ec6b1  b44e6feea99d8e7
# 293  b8bfff787f9431b  8123bb8f811250b
# 255  6f4491f8e22b695  9da59ac908212ad
# 481  53925a8f3f2ec4a  f871419ada1e282
# 339  a286eff253fdc3e  3145489fff9b0a7
# </div>

# %%
display(sql("select * from default.uk_500_626ee_csv order by first_name limit 5"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>first_name</th><th>last_name</th><th>company_name</th><th>address</th><th>city</th><th>county</th><th>postal</th><th>phone1</th><th>phone2</th><th>email</th><th>web</th></tr></thead><tbody><tr><td>Abraham</td><td>Cratch</td><td>Cavuto, John A</td><td>41 Benedict St</td><td>Aldborough Ward</td><td>Greater London</td><td>IG2 7QG</td><td>01599-245408</td><td>01695-305111</td><td>acratch@gmail.com</td><td>http://www.cavutojohna.co.uk</td></tr><tr><td>Adelle</td><td>Schantini</td><td>Creative Photography Inc</td><td>162 Grayson St</td><td>Greenlands Ward</td><td>Lancashire</td><td>FY2 0TD</td><td>01624-595660</td><td>01938-262356</td><td>adelle_schantini@yahoo.com</td><td>http://www.creativephotographyinc.co.uk</td></tr><tr><td>Adolph</td><td>Cunningham</td><td>Moorhead, Bridget Klein Esq</td><td>9874 Oakfield Rd</td><td>Redhill Ward</td><td>Tyne and Wear</td><td>SR5 5PT</td><td>01731-429712</td><td>01252-511174</td><td>adolph_cunningham@hotmail.com</td><td>http://www.moorheadbridgetkleinesq.co.uk</td></tr><tr><td>Ahmad</td><td>Alsaqri</td><td>Alliance Construction Co Inc</td><td>21 Pickwick St</td><td>Sutton cum Duckmanton</td><td>Derbyshire</td><td>S44 5DS</td><td>01567-555570</td><td>01852-550588</td><td>ahmad.alsaqri@yahoo.com</td><td>http://www.allianceconstructioncoinc.co.uk</td></tr><tr><td>Alaine</td><td>Raterman</td><td>Putnam Co Inc</td><td>1 Milton St</td><td>Little Missenden</td><td>Buckinghamshire</td><td>HP16 0DH</td><td>01927-151413</td><td>01525-172423</td><td>alaine@hotmail.com</td><td>http://www.putnamcoinc.co.uk</td></tr></tbody></table></div>
